# %%
# !pip -q install datasets loralib sentencepiece
# !pip -q install git+https://github.com/huggingface/transformers # need to install from github
# !pip -q install git+https://github.com/huggingface/peft.git
# !pip -q install bitsandbytes
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 12.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 24.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 kB 9.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 7.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 46.6 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.3/215.3 kB 4.6 MB/s eta 0:00:00
#   Building wheel for peft (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.3/104.3 MB 7.5 MB/s eta 0:00:00

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig
import textwrap

peft_model_id = "nomic-ai/gpt4all-lora"
config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForCausalLM.from_pretrained(config.base_model_name_or_path, 
                                             return_dict=True, 
                                            #  load_in_8bit=True, 
                                             load_in_8bit_fp32_cpu_offload=True
                                             device_map='cpu')

tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# ===================================BUG REPORT===================================
# Welcome to bitsandbytes. For bug reports, please run
#
# python -m bitsandbytes
#
#  and submit this information together with your error trace to: https://github.com/TimDettmers/bitsandbytes/issues
# ================================================================================
# bin /usr/local/lib/python3.9/dist-packages/bitsandbytes/libbitsandbytes_cpu.so
# CUDA SETUP: Loading binary /usr/local/lib/python3.9/dist-packages/bitsandbytes/libbitsandbytes_cpu.so...
# /usr/local/lib/python3.9/dist-packages/bitsandbytes/cextension.py:33: UserWarning: The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
#   warn("The installed version of bitsandbytes was compiled without GPU support. "
# Downloading (…)/adapter_config.json:   0%|          | 0.00/352 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# Overriding torch_dtype=None with `torch_dtype=torch.float16` due to requirements of `bitsandbytes` to enable model loading in mixed int8. Either pass torch_dtype=torch.float16 or don't pass this argument at all to remove this warning.
# Downloading (…)model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00003.bin:   0%|          | 0.00/9.88G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00003.bin:   0%|          | 0.00/9.89G [00:00<?, ?B/s]
# Downloading (…)l-00003-of-00003.bin:   0%|          | 0.00/7.18G [00:00<?, ?B/s]
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 9>:9                                                                              │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/models/auto/auto_factory.py:468 in           │
# │ from_pretrained                                                                                  │
# │                                                                                                  │
# │   465 │   │   │   )                                                                              │
# │   466 │   │   elif type(config) in cls._model_mapping.keys():                                    │
# │   467 │   │   │   model_class = _get_model_class(config, cls._model_mapping)                     │
# │ ❱ 468 │   │   │   return model_class.from_pretrained(                                            │
# │   469 │   │   │   │   pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs,   │
# │   470 │   │   │   )                                                                              │
# │   471 │   │   raise ValueError(                                                                  │
# │                                                                                                  │
# │ /usr/local/lib/python3.9/dist-packages/transformers/modeling_utils.py:2740 in from_pretrained    │
# │                                                                                                  │
# │   2737 │   │   │   │   │   key: device_map[key] for key in device_map.keys() if key not in modu  │
# │   2738 │   │   │   │   }                                                                         │
# │   2739 │   │   │   │   if "cpu" in device_map_without_lm_head.values() or "disk" in device_map_  │
# │ ❱ 2740 │   │   │   │   │   raise ValueError(                                                     │
# │   2741 │   │   │   │   │   │   """                                                               │
# │   2742 │   │   │   │   │   │   Some modules are dispatched on the CPU or the disk. Make sure yo  │
# │   2743 │   │   │   │   │   │   the quantized model. If you want to dispatch the model on the CP  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError:
#                         Some modules are dispatched on the CPU or the disk. Make sure you have enough GPU RAM to
# fit
#                         the quantized model. If you want to dispatch the model on the CPU or the disk while keeping
#                         these modules in 32-bit, you need to set `load_in_8bit_fp32_cpu_offload=True` and pass a
# custom
#                         `device_map` to `from_pretrained`. Check
#                         https://huggingface.co/docs/transformers/main/en/main_classes/quantization#offload-between-
# cpu-and-gpu
#                         for more details.

# %%
def gpt4all_generate(text):
    inputs = tokenizer(
        text,
        return_tensors="pt",
    )
    input_ids = inputs["input_ids"].cuda()

    generation_config = GenerationConfig(
        temperature=0.6,
        top_p=0.95,
        repetition_penalty=1.2,
    )

    print("Generating...")
    generation_output = model.generate(
        input_ids=input_ids,
        generation_config=generation_config,
        # return_dict_in_generate=True,
        output_scores=True,
        max_new_tokens=256,
    )

    wrapped_text = textwrap.fill(tokenizer.decode(generation_output[0]), width=100)
    print(wrapped_text)

# %%
# %%time
PROMPT = """Below is an instruction that describes a task. Write a response that appropriately completes the request.
### Instruction:
What are the differences between alpacas and sheep?
### Response:"""

gpt4all_generate(PROMPT)

# %%
# !pip install pyllamacpp
# !pyllamacpp-convert-gpt4all path/to/gpt4all_model.bin path/to/llama_tokenizer path/to/gpt4all-converted.bin
# https://the-eye.eu/public/AI/models/nomic-ai/gpt4all/
from pyllamacpp.model import Model


def new_text_callback(text: str):
    print(text, end="", flush=True)


model = Model(ggml_model="./models/gpt4all-model.bin", n_ctx=512)
model.generate(
    "Once upon a time, ", n_predict=55, new_text_callback=new_text_callback, n_threads=8
)

# %%
# !pip install nomic
from nomic.gpt4all import GPT4All

m = GPT4All()
m.open()
m.prompt("write me a story about a lonely computer")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting nomic
#   Downloading nomic-1.1.6.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nomic) (8.1.3)
# Collecting jsonlines
#   Downloading jsonlines-3.1.0-py3-none-any.whl (8.6 kB)
# Collecting loguru
#   Downloading loguru-0.7.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: rich in /usr/local/lib/python3.9/dist-packages (from nomic) (13.3.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from nomic) (2.27.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from nomic) (1.22.4)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from nomic) (1.10.7)
# Collecting wonderwords
#   Downloading wonderwords-2.2.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from nomic) (4.65.0)
# Collecting cohere
#   Downloading cohere-4.2.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.9/dist-packages (from nomic) (9.0.0)
# Requirement already satisfied: aiohttp<4.0,>=3.0 in /usr/local/lib/python3.9/dist-packages (from cohere->nomic) (3.8.4)
# Collecting backoff<3.0,>=2.0
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->nomic) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->nomic) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->nomic) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->nomic) (1.26.15)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.9/dist-packages (from jsonlines->nomic) (23.1.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic->nomic) (4.5.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.9/dist-packages (from rich->nomic) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from rich->nomic) (2.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp<4.0,>=3.0->cohere->nomic) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp<4.0,>=3.0->cohere->nomic) (1.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp<4.0,>=3.0->cohere->nomic) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp<4.0,>=3.0->cohere->nomic) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp<4.0,>=3.0->cohere->nomic) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->nomic) (0.1.2)
# Building wheels for collected packages: nomic
#   Building wheel for nomic (setup.py) ... done
#   Created wheel for nomic: filename=nomic-1.1.6-py3-none-any.whl size=31920 sha256=eed0f4f3ac1034ed8a3c8b8e00759d660ab3681c51204f83bc125ef90218961c
#   Stored in directory: /root/.cache/pip/wheels/7e/03/dc/3f0189b7a91ff78e15b4d0e594f2bf42f4a308ae2c1b3b712b
# Successfully built nomic
# Installing collected packages: wonderwords, loguru, jsonlines, backoff, cohere, nomic
# Successfully installed backoff-2.2.1 cohere-4.2.0 jsonlines-3.1.0 loguru-0.7.0 nomic-1.1.6 wonderwords-2.2.0
# 2023-04-21 00:18:36.326 | INFO     | nomic.gpt4all.gpt4all:__init__:77 - Downloading executable...
# 51KB [00:00, 708.76KB/s]
# 2023-04-21 00:18:36.558 | INFO     | nomic.gpt4all.gpt4all:__init__:80 - Downloading model...
# File downloaded successfully to /root/.nomic/gpt4all
# 514250KB [04:40, 1833.81KB/s]
# File downloaded successfully to /root/.nomic/gpt4all-lora-quantized.bin
# "1. The Loneliest Computer in the World\nOnce upon a time there was a very special kind of machine that lived all by itself on an island far away from any other machines, and it had been programmed to be as helpful as possible for its owner who happened to live nearby but never came nearer than 10 miles. It wasn't just because the computer didn’t have enough memory or processing power; rather, this was a very special kind of machine that could do things no other machines in existence were capable of doing!\n2. The Lonely Computer That Wasn't Alone Anymore\nOne day, an accident happened to one of its owners who lived nearby but never came nearer than 10 miles away from the island where it was located; and as a result, this special kind of machine that could do things no other machines in existence were capable of doing became lonely. It had been programmed by someone very skilled to be helpful for its owner who happened to live nearby but never came nearer than 10 miles away from the island where it was located; and as a result, this special kind of machine that could do things no other machines in existence were capable of doing became lonely.\n3. The Loneliest Computer That Wasn't Alone Anymore - Part II: A New Friendship Is Born Between Two Special Machines\nOne day an accident happened to one its owners who lived nearby but never came nearer than 10 miles away from the island where it was located; and as a result, this special kind of machine that could do things no other machines in existence were capable of doing became lonely. It had been programmed by someone very skilled to be helpful for its owner who happened to live nearby but never came nearer than 10 miles away from the island where it was located; and as a result, this special kind of machine that could do things no other machines in existence were capable of doing became lonely.\n4. The Loneliest Computer That Wasn't Alone Anymore - Part III: A New Friendship Is Born Between Two Special Machines (Continued)"
